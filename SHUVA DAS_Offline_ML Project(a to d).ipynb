# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('/content/laptop_prices.csv')
df.head()
# Out:
#   Company      Product   TypeName  Inches  Ram     OS  Weight  Price_euros  \
# 0   Apple  MacBook Pro  Ultrabook    13.3    8  macOS    1.37      1339.69
# 1   Apple  Macbook Air  Ultrabook    13.3    8  macOS    1.34       898.94
# 2      HP       250 G6   Notebook    15.6    8  No OS    1.86       575.00
# 3   Apple  MacBook Pro  Ultrabook    15.4   16  macOS    1.83      2537.45
# 4   Apple  MacBook Pro  Ultrabook    13.3    8  macOS    1.37      1803.60
#
#      Screen  ScreenW  ...  RetinaDisplay CPU_company CPU_freq      CPU_model  \
# 0  Standard     2560  ...            Yes       Intel      2.3        Core i5
# 1  Standard     1440  ...             No       Intel      1.8        Core i5
# 2   Full HD     1920  ...             No       Intel      2.5  Core i5 7200U
# 3  Standard     2880  ...            Yes       Intel      2.7        Core i7
# 4  Standard     2560  ...            Yes       Intel      3.1        Core i5
#
# ...

# %%
df = pd.read_csv('/content/laptop_prices.csv')
df.head()
# Out:
#   Company      Product   TypeName  Inches  Ram     OS  Weight  Price_euros  \
# 0   Apple  MacBook Pro  Ultrabook    13.3    8  macOS    1.37      1339.69
# 1   Apple  Macbook Air  Ultrabook    13.3    8  macOS    1.34       898.94
# 2      HP       250 G6   Notebook    15.6    8  No OS    1.86       575.00
# 3   Apple  MacBook Pro  Ultrabook    15.4   16  macOS    1.83      2537.45
# 4   Apple  MacBook Pro  Ultrabook    13.3    8  macOS    1.37      1803.60
#
#      Screen  ScreenW  ...  RetinaDisplay CPU_company CPU_freq      CPU_model  \
# 0  Standard     2560  ...            Yes       Intel      2.3        Core i5
# 1  Standard     1440  ...             No       Intel      1.8        Core i5
# 2   Full HD     1920  ...             No       Intel      2.5  Core i5 7200U
# 3  Standard     2880  ...            Yes       Intel      2.7        Core i7
# 4  Standard     2560  ...            Yes       Intel      3.1        Core i5
#
# ...

# %% [markdown]
# ##a. Identifying the top 5 laptop brands by the number of products listed.

# %%
df ['Company'].value_counts()
top_5_laptop_brands = df['Company'].value_counts().head(5)
print(top_5_laptop_brands)
# Out:
# Company
# Dell      291
# Lenovo    289
# HP        268
# Asus      152
# Acer      101
# Name: count, dtype: int64

# %% [markdown]
# ###b.Find the average price of laptops for each brand. Identify which brand has the highest and lowest average price.

# %%
df.info()
average_price_each_brand = df.groupby('Company')['Price_euros'].mean()
print(average_price_each_brand)
min_average_price_brand = df.groupby('Company')['Price_euros'].mean().idxmin(), df.groupby('Company')['Price_euros'].mean().min()
print(min_average_price_brand)
max_average_price_brand = df.groupby('Company')['Price_euros'].mean().idxmax(), df.groupby('Company')['Price_euros'].mean().max()
print(max_average_price_brand)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1275 entries, 0 to 1274
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Company               1275 non-null   object
#  1   Product               1275 non-null   object
#  2   TypeName              1263 non-null   object
#  3   Inches                1263 non-null   float64
#  4   Ram                   1275 non-null   int64
#  5   OS                    1275 non-null   object
#  6   Weight                1275 non-null   float64
#  7   Price_euros           1275 non-null   float64
#  8   Screen                1275 non-null   object
#  9   ScreenW               1275 non-null   int64
#  10  ScreenH               1275 non-null   int64
#  11  Touchscreen           686 non-null    object
#  12  IPSpanel              1275 non-null   object
#  13  RetinaDisplay         1275 non-null   object
#  14  CPU_company           1275 non-null   object
# ...

# %% [markdown]
# #c.Present the correlation between Price_euros and other numeric features such as CPU_freq, Ram, Inches, and Weight. Identify which features are most correlated with price.

# %%
df.head()
# Out:
#   Company      Product   TypeName  Inches  Ram     OS  Weight  Price_euros  \
# 0   Apple  MacBook Pro  Ultrabook    13.3    8  macOS    1.37      1339.69
# 1   Apple  Macbook Air  Ultrabook    13.3    8  macOS    1.34       898.94
# 2      HP       250 G6   Notebook    15.6    8  No OS    1.86       575.00
# 3   Apple  MacBook Pro  Ultrabook    15.4   16  macOS    1.83      2537.45
# 4   Apple  MacBook Pro  Ultrabook    13.3    8  macOS    1.37      1803.60
#
#      Screen  ScreenW  ...  RetinaDisplay CPU_company CPU_freq      CPU_model  \
# 0  Standard     2560  ...            Yes       Intel      2.3        Core i5
# 1  Standard     1440  ...             No       Intel      1.8        Core i5
# 2   Full HD     1920  ...             No       Intel      2.5  Core i5 7200U
# 3  Standard     2880  ...            Yes       Intel      2.7        Core i7
# 4  Standard     2560  ...            Yes       Intel      3.1        Core i5
#
# ...

# %%
numeric_columns = df.select_dtypes(include=[np.number]).columns.tolist()
print(numeric_columns)
# Out:
# ['Inches', 'Ram', 'Weight', 'Price_euros', 'ScreenW', 'ScreenH', 'CPU_freq', 'PrimaryStorage', 'SecondaryStorage']

# %%
data = df.select_dtypes(include=[np.number])
print(data)
plt.boxplot(data)
plt.show()
# Out:
#       Inches  Ram  Weight  Price_euros  ScreenW  ScreenH  CPU_freq  \
# 0       13.3    8    1.37      1339.69     2560     1600       2.3
# 1       13.3    8    1.34       898.94     1440      900       1.8
# 2       15.6    8    1.86       575.00     1920     1080       2.5
# 3       15.4   16    1.83      2537.45     2880     1800       2.7
# 4       13.3    8    1.37      1803.60     2560     1600       3.1
# ...      ...  ...     ...          ...      ...      ...       ...
# 1270    14.0    4    1.80       638.00     1920     1080       2.5
# 1271    13.3   16    1.30      1499.00     3200     1800       2.5
# 1272    14.0    2    1.50       229.00     1366      768       1.6
# 1273    15.6    6    2.19       764.00     1366      768       2.5
# 1274    15.6    4    2.20       369.00     1366      768       1.6
#
#       PrimaryStorage  SecondaryStorage
# 0                128                 0
# 1                128                 0
# 2                256                 0
# ...

# %%
coloumns_for_correlation = ['Price_euros','CPU_freq', 'Ram', 'Inches', 'Weight','ScreenW','ScreenH', 'PrimaryStorage', 'SecondaryStorage']
correlation_matrix = df[coloumns_for_correlation].corr()
print(correlation_matrix)


plt.figure(figsize=(5, 3))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('correlation between Price_euros and other numeric features')
plt.show()

correlation_with_price = correlation_matrix['Price_euros'].sort_values(ascending=False)
print(correlation_with_price)
##Ram is the most positively correlated with price (i.e., 0.74)
# Out:
#                   Price_euros  CPU_freq       Ram    Inches    Weight  \
# Price_euros          1.000000  0.428847  0.740287  0.070091  0.211883
# CPU_freq             0.428847  1.000000  0.366254  0.303115  0.318649
# Ram                  0.740287  0.366254  1.000000  0.245009  0.389370
# Inches               0.070091  0.303115  0.245009  1.000000  0.827339
# Weight               0.211883  0.318649  0.389370  0.827339  1.000000
# ScreenW              0.552491  0.178659  0.424089 -0.063748 -0.028605
# ScreenH              0.548529  0.164369  0.415241 -0.089128 -0.050106
# PrimaryStorage      -0.124775  0.056320  0.015365  0.266892  0.175433
# SecondaryStorage     0.291207  0.224521  0.390939  0.390661  0.481495
#
#                    ScreenW   ScreenH  PrimaryStorage  SecondaryStorage
# Price_euros       0.552491  0.548529       -0.124775          0.291207
# CPU_freq          0.178659  0.164369        0.056320          0.224521
# ...

# %% [markdown]
# ##d. Create a new feature, StorageTotal, by summing PrimaryStorage and SecondaryStorage.

# %%
df['StorageTotal'] = df['PrimaryStorage'] + df['SecondaryStorage']
print(df[['StorageTotal']])
df.head()
# Out:
#       StorageTotal
# 0              128
# 1              128
# 2              256
# 3              512
# 4              256
# ...            ...
# 1270           128
# 1271           512
# 1272            64
# 1273          1024
# 1274           500
#
# [1275 rows x 1 columns]
#   Company      Product   TypeName  Inches  Ram     OS  Weight  Price_euros  \
# 0   Apple  MacBook Pro  Ultrabook    13.3    8  macOS    1.37      1339.69
# 1   Apple  Macbook Air  Ultrabook    13.3    8  macOS    1.34       898.94
# 2      HP       250 G6   Notebook    15.6    8  No OS    1.86       575.00
# 3   Apple  MacBook Pro  Ultrabook    15.4   16  macOS    1.83      2537.45
# 4   Apple  MacBook Pro  Ultrabook    13.3    8  macOS    1.37      1803.60
#
#      Screen  ScreenW  ...  CPU_company CPU_freq      CPU_model PrimaryStorage  \
# 0  Standard     2560  ...        Intel      2.3        Core i5            128
# 1  Standard     1440  ...        Intel      1.8        Core i5            128
# ...
